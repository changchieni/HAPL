# %%
print('I′m a student ')
# Out:
# I′m a student

# %%
x1=float(input('請輸入x1值'))
y1=float(input('請輸入y1值'))
x2=float(input('請輸入x2值'))
y2=float(input('請輸入y2值'))
AB=((x2-x1)**2+(y2-y1)**2)**0.5
print("AB距離=",AB)
# Out:
# 請輸入x1值1
# 請輸入y1值1
# 請輸入x2值4
# 請輸入y2值5
# AB距離= 5.0

# %%
h=float(input("請輸入身高(cm)"))
w=float(input("請輸入體重(kg)"))
h/=100
h*=h
w/=h
BMI=w
print("BMI=",BMI)
# Out:
# 請輸入身高(cm)152
# 請輸入體重(kg)45
# BMI= 19.47714681440443
