# %%
a='C,B,A'
b=['F','G','H']
a=a.split(',')
a+=b
a[0]='K'
print(a)
c=a.pop(2)
print(c)
del a[1:4]
a.append('U')
print(a)
# Out:
# ['K', 'B', 'A', 'F', 'G', 'H']
# A
# ['K', 'H', 'U']

# %%
a=input('請輸入一個八位數的數字')
print(a[4])
# Out:
# 請輸入一個八位數的數字01234567
# 4

# %%
a='My ID is B1206003'
a=a.split(' ')
print("此字串共有",len(a),"字")
print("此ID共有",len(a[3]),"元素")
# Out:
# 此字串共有 4 字
# 此ID共有 8 元素

# %%
a='I′m a student'
b=a.split()
c=b[0].split("′")
print(c[1])
# Out:
# m
